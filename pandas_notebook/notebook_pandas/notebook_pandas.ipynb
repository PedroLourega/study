# %%
import pandas as pd

# %%
path_file = 'data/folha_ponto_empresa.xlsx'

df = pd.read_excel(path_file)

df
# Out:
#                Nome        Data              Atividade         Projeto  \
# 0         Ana Silva  14/04/2026            Treinamento    Internal ERP
# 1         Ana Silva  13/04/2026           Planejamento      Mobile App
# 2         Ana Silva  12/04/2026  Análise de Requisitos           Alpha
# 3         Ana Silva  11/04/2026           Documentação            Beta
# 4         Ana Silva  10/04/2026  Análise de Requisitos            Beta
# ..              ...         ...                    ...             ...
# 245  Zuleica Santos  14/04/2026                Suporte  Migração Cloud
# 246  Zuleica Santos  13/04/2026            Treinamento            Beta
# 247  Zuleica Santos  12/04/2026        Reunião Interna  Migração Cloud
# 248  Zuleica Santos  11/04/2026           Documentação           Alpha
# 249  Zuleica Santos  10/04/2026           Documentação      Mobile App
#
#     Hora Entrada 1 Hora Saida 1 Hora Entrada 2 Hora Saida 2 Hora Entrada 3  \
# ...
